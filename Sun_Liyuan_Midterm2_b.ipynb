# %% [markdown]
# Before you turn this midterm in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name below:

# %%
NAME = "Liyuan Sun"

# %% [markdown]
# ---

# %% [markdown]
# # Midterm 2
#
# In all coding problems, please comment your code sufficiently well so that I can follow your thought process. You may use the optional Markdown box for additional explanations - this is especially relevant if your code does not run as expected. Please **do not** add, delete, or change the type of any of the cells in this notebook.
#
# ## Instructions
# - There are three problems on this exam. Total number of points is 100.
# - You have 70 minutes to complete this exam. And five minutes to download and upload files.
# - All of your work must be in this Jupyter Notebook. You can perform scratch work in another Notebook but only the work contained in *this* notebook will be considered for grading.
# - You may use your textbooks, your class notes, and the internet on this exam.
# - You may **not** use the help of any other people (other than the instructor) on the exam.
# - If you have a question, you may ask me on zoom during the exam.
# - Good luck!

# %% [markdown]
# **Honor Pledge:** By typing your name into the Markdown box below, you pledge to not have given or received aid by any other person on this exam.

# %% [markdown]
# Liyuan Sun

# %% [markdown]
# ## Problem 1 (40 points)
#
# The Pandas data frame generated by the code below contains assessment results for 10 students. Students were instructed either online or through in-person classes. Each student was taught four different subjects and took three different tests in each subject to generate assessment scores. The student names are replaced by anonymized ID's.
#
# Execute the code below to import packages we'll need for this exam and to load the assessment data as a data frame.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({'Student ID': ['SQ_4', 'TN_0', 'AP_8', 'NO_6', 'XI_0', 'YO_6', 'TB_0', 'BB_2','BB_2', 'DK_1', 'OO_5', 'UD_5', 'SQ_4', 'SQ_4', 'TB_0', 'AP_8','UD_5', 'SQ_4', 'TB_0', 'DK_1', 'AP_8', 'BB_2', 'UD_5', 'TN_0', 'XI_0', 'TN_0', 'BB_2', 'SQ_4', 'NO_6', 'TN_0', 'YO_6', 'TB_0', 'TB_0', 'DK_1', 'OO_5', 'TN_0', 'NO_6', 'OO_5', 'NO_6', 'TN_0', 'AP_8', 'SG_7', 'YO_6', 'TB_0', 'TB_0', 'UD_5', 'SQ_4', 'TB_0', 'OO_5', 'DK_1', 'SG_7', 'UD_5', 'XI_0', 'DK_1', 'SG_7', 'UD_5', 'SG_7', 'OO_5', 'SG_7', 'UD_5', 'YO_6', 'AP_8', 'YO_6', 'XI_0', 'OO_5', 'NO_6', 'TN_0', 'NO_6', 'OO_5', 'BB_2', 'TN_0', 'YO_6', 'UD_5', 'XI_0', 'BB_2', 'DK_1', 'XI_0', 'XI_0', 'NO_6', 'AP_8', 'DK_1', 'DK_1', 'SQ_4', 'NO_6', 'SG_7', 'SG_7', 'BB_2', 'SQ_4', 'UD_5', 'XI_0', 'NO_6', 'AP_8', 'YO_6', 'SQ_4', 'YO_6', 'AP_8', 'OO_5', 'SQ_4', 'SG_7', 'NO_6', 'SG_7', 'YO_6', 'BB_2', 'TN_0', 'TN_0', 'YO_6', 'UD_5', 'OO_5', 'AP_8', 'TB_0', 'AP_8', 'SG_7','XI_0', 'DK_1', 'XI_0', 'DK_1', 'BB_2', 'OO_5', 'TB_0', 'BB_2'],
                    'Subject': ['Reading', 'Science', 'Writing', 'Reading', 'Writing', 'Math', 'Writing', 'Math', 'Writing', 'Math', 'Science', 'Science', 'Math', 'Math', 'Math', 'Reading', 'Science', 'Science', 'Reading', 'Math', 'Math', 'Reading', 'Science', 'Writing', 'Reading', 'Science', 'Writing', 'Science', 'Science', 'Math', 'Science', 'Writing', 'Reading', 'Writing', 'Writing', 'Science', 'Math', 'Reading', 'Science', 'Math', 'Writing', 'Math', 'Science', '
#     Student ID  Subject Delivery Method  Assessment Result
# 0         SQ_4  Reading          online              30.49
# 1         TN_0  Science          online              18.84
# 2         AP_8  Writing       in-person              42.56
# 3         NO_6  Reading       in-person              47.89
# 4         XI_0  Writing       in-person              59.29
# ..         ...      ...             ...                ...
# 115       DK_1  Writing          online              39.20
# 116       BB_2  Reading       in-person              92.58
# 117       OO_5  Writing       in-person              19.91
# 118       TB_0     Math          online              74.31
# 119       BB_2     Math       in-person              59.39
#
# [120 rows x 4 columns]

# %% [markdown]
# (a) (20 points) Write a Python function named "delivery_method" that takes as input the ID of a student as a string and returns (as a string) the delivery method that the student was instructed with.

# %%
def delivery_method(ID):
    return data[data['Student ID'] == ID]['Delivery Method']
    
# Check your code
delivery_method('DK_1') == "online"
# Out:
# 9      True
# 19     True
# 33     True
# 49     True
# 53     True
# 75     True
# 80     True
# 81     True
# 113    True
# 115    True
# Name: Delivery Method, dtype: bool

# %% [markdown]
# **Optional:** You may provide optional comments on your function below.

# %% [markdown]
# Considering there are more than one observations with ID="DK_1", there should be more than one 'Delivery Method' equal to 'online'. And we can see the index of that observations.

# %% [markdown]
# (b) (20 points) Use the Pandas "groupby" method to obtain the mean and the standard deviation of "Assessment Results" for each Subject (across all students and repeated tests), separately for online and in-person instruction methods.
# Save the results in a new data frame. Your new data frame should have exactly the columns "Delivery Method", "Subject", "Mean Result", "Standard Deviation" (in this order). Display your new data frame to the console so that the grader can see it.
#
# **Hint:** You can check your work by comparing your data frame to the data frame provided below. The order of your rows does not need to be identical to the order of the rows shown below.

# %%
target = pd.DataFrame(columns=["Mean Result", "Standard Deviation"])
target['Mean Result'] = data.groupby(['Delivery Method','Subject'])['Assessment Result'].mean()
target['Standard Deviation'] = data.groupby(['Delivery Method','Subject'])['Assessment Result'].std()
target
# Out:
#                          Mean Result  Standard Deviation
# Delivery Method Subject
# in-person       Math       61.226667           17.384149
#                 Reading    53.168000           21.354173
#                 Science    49.853333           22.100002
#                 Writing    38.513333           22.657789
# online          Math       64.331333           19.619819
#                 Reading    33.403333           21.704765
#                 Science    47.367333           19.290994
#                 Writing    52.752667           17.982067

# %% [markdown]
# **Optional:** You may provide optional comments on your code below.

# %% [markdown]
# YOUR ANSWER HERE

# %%
Delivery = ['in-person']*4+['online']*4
Subject = ['Math', 'Reading', 'Science', 'Writing']*2
Mean = [61.22666667, 53.168     , 49.85333333, 38.51333333, 64.33133333, 33.40333333, 47.36733333, 52.75266667]
Std = [17.38414905, 21.3541733 , 22.10000248, 22.65778853, 19.61981865, 21.70476533, 19.290994  , 17.98206744]

aggregated_data = pd.DataFrame({'Delivery Method': Delivery, 'Subject': Subject, "Mean Result":Mean, "Standard Deviation": Std})
aggregated_data
# Out:
#   Delivery Method  Subject  Mean Result  Standard Deviation
# 0       in-person     Math    61.226667           17.384149
# 1       in-person  Reading    53.168000           21.354173
# 2       in-person  Science    49.853333           22.100002
# 3       in-person  Writing    38.513333           22.657789
# 4          online     Math    64.331333           19.619819
# 5          online  Reading    33.403333           21.704765
# 6          online  Science    47.367333           19.290994
# 7          online  Writing    52.752667           17.982067

# %% [markdown]
# ## Problem 2 (40 points)
#
# The data frame ```aggregated_data``` defined above (make sure to run the cell so that you can see the data frame) has aggregated test results (means and standard deviations) across all students and assessments where students were instructed in the same subject using the same delivery method.
#
# Use the object oriented way (fig, ax) in Matplotlib to produce a side-by-side bar graph of the mean Assessment Result as a function of Subject with separate bars for on-line and in-person instruction. You can see what your resulting graph should look like in the pdf file you can download from Canvas (where you also downloaded this Jupyter Notebook).
#
# * Subject labels on the x-axis
# * Height of bars should represent mean assessment results
# * Create two bars for each subject (one for online instruction, one for in-person instruction)
# * Give the bars for online and in-person instruction different colors (green for online, blue for in-person)
# * Turn the Subject labels on the x-axis 45 degrees
# * Include error bars that represent the standard deviations of results (no, we haven't done this in class)
# * Put "caps" (short horizontal lines) on the top and bottom of your error bars (no, we haven't done this in class)
# * Give your graph the title "Mean assessment results by subject and delivery method" in a font larger than that you used for the axes
# * Label the y-axis with "Mean assessment result"
# * Include a legend (showing which color represents which delivery method)
#
# **Disclaimer:** We did discuss how to do most but *not all* of these things in class. Look up everything you don't know how to do (yet) in the Matplotlib documentation.

# %%
online = aggregated_data[aggregated_data['Delivery Method']=='online']
inperson = aggregated_data[aggregated_data['Delivery Method']=='in-person']

subject = ['Math','Reading','Science','Writing']
x_pos = np.arange(len(subject))

mean_online = online['Mean Result']
mean_inperson = inperson['Mean Result']
error_online = online['Standard Deviation']
error_inperson = inperson['Standard Deviation']

fig, ax = plt.subplots()

ax.bar(x_pos, mean_online, yerr=error_online, width = -0.35, align = 'edge', label = 'online', color = 'g')
ax.bar(x_pos, mean_inperson, yerr=error_inperson, width = -0.35, align = 'edge', label ='in-person', color = 'b')

ax.set_ylabel('Mean Assessment Result')
ax.set_xticks(x_pos, subject)
ax.set_title('Mean assessment results by subject and delivery method')
plt.legend();

# %% [markdown]
# **Optional:** You may provide optional comments on your code and or graph below.

# %% [markdown]
# Dear Dr. Bremer,

# %% [markdown]
# ## Problem 3 (20 points)
#
#
# The "mystery_function" defined in the code box below takes as its input a two-dimensional NumPy array $A$ of integers, as well as two additional integers $p$ and $q$. Explain what the function does.  Your explanation should be a succinct (brief and clear) summary in English. A line-by-line translation of the code into English is *not* a succinct summary.
#
# Recall, that you are allowed to run (parts or all of) this code in a scratch Jupyter Notebook. But please remember to not add, delete or change any of the cells in *this* notebook.

# %%
def mystery_function(A,p,q):
    (n,m) = A.shape
    foo = False
    if max(p,q)>m | (p==q):
        foo = "not possible"
    else:
        foo = A[A.T[p].argsort()]
        bar = set(A.T[p])
        for x in bar:
            Ax = A[A.T[p]==x]
            foo[foo.T[p]==x] = Ax[Ax.T[q].argsort()]
    return foo

# %%
def mystery_function(A,p,q):
    (n,m) = A.shape                # n rows, m columns
    foo = False
    
    if max(p,q)>m | (p==q):        # if either of the conditions success, return 'not possible' 
        foo = "not possible"
        
    else:
        foo = A[A.T[p].argsort()]  # sort in increasing order
        bar = set(A.T[p])          # transpose the A matrix in
        
        for x in bar:
            Ax = A[A.T[p]==x]
            foo[foo.T[p]==x] = Ax[Ax.T[q].argsort()]
            
    return foo

mystery_function(np.array([3,0,3,0]),6,5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-525b96d6eba1> in <module>
#      16     return foo
#      17
# ---> 18 mystery_function(np.array([3,0,3,0]),6,5)
#
# <ipython-input-66-525b96d6eba1> in mystery_function(A, p, q)
#       1 def mystery_function(A,p,q):
# ----> 2     (n,m) = A.shape                # n rows, m columns
#       3     foo = False
#       4
#       5     if max(p,q)>m | (p==q):        # if either of the conditions success, return 'not possible'
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# Your description of what this function does goes here:

# %% [markdown]
# **Answer:** This is sorting function. The goal is to find the indexs (positions) of the.
